# %%
from BlackScholes import BlackScholes
from StockData import StockData
from VolatilitySurface import VolatilitySurface
import warnings
warnings.filterwarnings('ignore')

# %%
# Set the parameters for the tests
ticker_symbol = 'AAPL'
start_date = '2020-01-01'
end_date = '2021-12-31'
vol_surface_file = 'volatility_surface_plot'

# %%
# Testing BlackScholes class
print('\nTesting BlackScholes class:')
bs = BlackScholes(S=100, K=150, T=1, r=0.05, sigma=0.3)
print(f'Call Option Price: {bs.call_option_price()}')
print(f'Put Option Price: {bs.put_option_price()}')

# %%
# Testing StockData class
print('\nTesting StockData class:')
stock = StockData(ticker_symbol)
stock.fetch_price(start_date, end_date)
print(stock.stock_data)
stock.fetch_chain()
print(stock.options_chain)

# %%
stock.options_chain

# %%
filtered_options = stock.options_chain[stock.options_chain['lastTradeDate'] >= '2024-08-02']
filtered_options

# %%
# Testing VolatilitySurface class
print('\nTesting VolatilitySurface class:')
options = filtered_options[filtered_options['optionType'] == 'Call']

vol_surface = VolatilitySurface(options)
vol_surface.plot_surface('call_vol_surface', plot_points=True)

# %%
import warnings
warnings.filterwarnings('ignore')
from Portfolio import Portfolio
from StockData import StockData
portfolio = Portfolio()

stock_data_aapl = StockData("AAPL")
stock_data_msft = StockData("MSFT")
stock_data_goog = StockData("GOOG")

portfolio.add_stock(stock_data_aapl, 10)
portfolio.add_stock(stock_data_msft, 15)
portfolio.add_stock(stock_data_goog, 5)

# set the date range
start_date = "2020-01-01"
end_date = "2021-12-31"

# test the portfolio's calculations
print("\nTesting portfolio calculations..")
print("\nPortfolio Return:")
print(portfolio.calculate_portfolio_return(start_date, end_date))

# %%
from OptionData import OptionData

aapl_options = OptionData('AAPL')
aapl_options
# Out:
# /Users/robertschedler/DataspellProjects/finlab/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Downloading historical data for option AAPL240809C00100000...
# Downloading historical data for option AAPL240809C00125000...
# Downloading historical data for option AAPL240809C00130000...
# Downloading historical data for option AAPL240809C00140000...
# Downloading historical data for option AAPL240809C00145000...
# Downloading historical data for option AAPL240809C00150000...
# Downloading historical data for option AAPL240809C00155000...
# Downloading historical data for option AAPL240809C00160000...
# Downloading historical data for option AAPL240809C00170000...
# Downloading historical data for option AAPL240809C00175000...
# Downloading historical data for option AAPL240809C00180000...
# Downloading historical data for option AAPL240809C00185000...
# Downloading historical data for option AAPL240809C00190000...
# Downloading historical data for option AAPL240809C00195000...
# Downloading historical data for option AAPL240809C00197500...
# Downloading historical data for option AAPL240809C00200000...
# Downloading historical data for option AAPL240809C00202500...
# Downloading historical data for option AAPL240809C00205000...
# Downloading historical data for option AAPL240809C00207500...
# Downloading historical data for option AAPL240809C00210000...
# Downloading historical data for option AAPL240809C00212500...
# Downloading historical data for option AAPL240809C00215000...
# Downloading historical data for option AAPL240809C00217500...
# Downloading historical data for option AAPL240809C00220000...
# Downloading historical data for option AAPL240809C00222500...
# Downloading historical data for option AAPL240809C00225000...
# Downloading historical data for option AAPL241018C00145000...
# Downloading historical data for option AAPL241018C00150000...
# Downloading historical data for option AAPL241018C00155000...
# Downloading historical data for option AAPL241018C00160000...
# Downloading historical data for option AAPL241018C00165000...
# Downloading historical data for option AAPL241018C00170000...
# Downloading historical data for option AAPL241018C00175000...
# Downloading historical data for option AAPL241018C00180000...
# Downloading historical data for option AAPL241018C00185000...
# Downloading historical data for option AAPL241018C00190000...
# Downloading historical data for option AAPL241018C00195000...
# Downloading historical data for option AAPL241018C00200000...
# Downloading historical data for option AAPL241018C00205000...
# Downloading historical data for option AAPL241018C00210000...
# Downloading historical data for option AAPL241018C00215000...
# Downloading historical data for option AAPL241018C00220000...
# Downloading historical data for option AAPL241018C00225000...
# Downloading historical data for option AAPL241018C00230000...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from OptionData import OptionData
# ----> 3 aapl_options = OptionData('AAPL')
#       4 aapl_options
#
# File ~/DataspellProjects/finlab/OptionData.py:9, in OptionData.__init__(self, ticker_symbol)
#       7 self.ticker = yf.Ticker(ticker_symbol)
#       8 self.options_data = {}
# ----> 9 self.download_option_data()
#
# File ~/DataspellProjects/finlab/OptionData.py:28, in OptionData.download_option_data(self)
#      26 try:
#      27     option_ticker = yf.Ticker(option_symbol)
# ---> 28     self.options_data[option_symbol] = option_ticker.history(period="max")
#      29 except Exception as e:
#      30     print(f"Could not download historical data for option {option_symbol}: {e}")
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/yfinance/base.py:78, in TickerBase.history(self, *args, **kwargs)
#      76 @utils.log_indent_decorator
#      77 def history(self, *args, **kwargs) -> pd.DataFrame:
# ---> 78     return self._lazy_load_price_history().history(*args, **kwargs)
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/yfinance/scrapers/history.py:143, in PriceHistory.history(self, period, interval, start, end, prepost, actions, auto_adjust, back_adjust, repair, keepna, proxy, rounding, timeout, raise_errors)
#     141         get_fn = self._data.cache_get
#     142 try:
# --> 143     data = get_fn(
#     144         url=url,
#     145         params=params,
#     146         proxy=proxy,
#     147         timeout=timeout
#     148     )
#     149     if "Will be right back" in data.text or data is None:
#     150         raise RuntimeError("*** YAHOO! FINANCE IS CURRENTLY DOWN! ***\n"
#     151                            "Our engineers are working quickly to resolve "
#     152                            "the issue. Thank you for your patience.")
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/yfinance/data.py:366, in YfData.get(self, url, user_agent_headers, params, proxy, timeout)
#     356     cookies = None
#     358 request_args = {
#     359     'url': url,
#     360     'params': {**params, **crumbs},
#    (...)
#     364     'headers': user_agent_headers or self.user_agent_headers
#     365 }
# --> 366 response = self._session.get(**request_args)
#     367 utils.get_yf_logger().debug(f'response code={response.status_code}')
#     368 if response.status_code >= 400:
#     369     # Retry with other cookie strategy
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/DataspellProjects/finlab/venv/lib/python3.9/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
